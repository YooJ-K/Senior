# %%
# !mkdir convert2Yolo
# !cd convert2Yolo
# !git init
# !git remote add origin https://github.com/ssaru/convert2Yolo.git
# !git pull origin master

# %%
# !pip3 install -r requirements.txt
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 202, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 202 (delta 4), reused 6 (delta 4), pack-reused 188
# Receiving objects: 100% (202/202), 1000.23 KiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# From https://github.com/ssaru/convert2Yolo
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master
# ...
#      |████████████████████████████████| 2.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 89 kB 10.1 MB/s
# ...
#      |████████████████████████████████| 12.6 MB 85 kB/s
# ...
#      |████████████████████████████████| 4.9 MB 53.2 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 212 kB 57.6 MB/s
# ...
#      |████████████████████████████████| 510 kB 44.1 MB/s
# ...

# %%
# !python example.py --datasets COCO --img_path ./images/val2017/ --label ./annotations/instances_val2017.json --convert_output_path ./val --img_type ".jpg" --manifest_path ./ --cls_list_file voc.names2
